# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Reading the dataset

# %%
data=pd.read_csv("indian_liver_patient.csv")

# %% [markdown]
# Exploratory data analysis

# %%
data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
data.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
data.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# std                  182.620356                  288.918529        1.085451
# min                   10.000000                   10.000000        2.700000
# 25%                   23.000000                   25.000000        5.800000
# 50%                   35.000000                   42.000000        6.600000
# 75%                   60.500000                   87.000000        7.200000
# max                 2000.000000                 4929.000000        9.600000
#
#           Albumin  Albumin_and_Globulin_Ratio     Dataset
# count  583.000000                  579.000000  583.000000
# mean     3.141852                    0.947064    1.286449
# std      0.795519                    0.319592    0.452490
# min      0.900000                    0.300000    1.000000
# 25%      2.600000                    0.700000    1.000000
# 50%      3.100000                    0.930000    1.000000
# 75%      3.800000                    1.100000    2.000000
# max      5.500000                    2.800000    2.000000

# %% [markdown]
# Checking for null values and handling null values

# %%
data.isnull()
# Out:
#        Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0    False   False            False             False                 False
# 1    False   False            False             False                 False
# 2    False   False            False             False                 False
# 3    False   False            False             False                 False
# 4    False   False            False             False                 False
# ..     ...     ...              ...               ...                   ...
# 578  False   False            False             False                 False
# 579  False   False            False             False                 False
# 580  False   False            False             False                 False
# 581  False   False            False             False                 False
# 582  False   False            False             False                 False
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                       False                       False           False
# 1                       False                       False           False
# 2                       False                       False           False
# 3                       False                       False           False
# 4                       False                       False           False
# ..                        ...                         ...             ...
# 578                     False                       False           False
# 579                     False                       False           False
# 580                     False                       False           False
# 581                     False                       False           False
# 582                     False                       False           False
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      False                       False    False
# 1      False                       False    False
# 2      False                       False    False
# 3      False                       False    False
# 4      False                       False    False
# ..       ...                         ...      ...
# 578    False                       False    False
# 579    False                       False    False
# 580    False                       False    False
# 581    False                       False    False
# 582    False                       False    False
#
# [583 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
data.mode()
# Out:
#     Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0  60.0   Male              0.8               0.2                   198
# 1   NaN    NaN              NaN               NaN                   215
# 2   NaN    NaN              NaN               NaN                   298
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                      25.0                        23.0             7.0
# 1                       NaN                         NaN             NaN
# 2                       NaN                         NaN             NaN
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.0                         1.0      1.0
# 1      NaN                         NaN      NaN
# 2      NaN                         NaN      NaN

# %%
data['Albumin_and_Globulin_Ratio'].median()
# Out:
# 0.93

# %%
data.loc[data['Albumin_and_Globulin_Ratio'].isnull()==True]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 209   45  Female              0.9               0.3                   189
# 241   51    Male              0.8               0.2                   230
# 253   35  Female              0.6               0.2                   180
# 312   27    Male              1.3               0.6                   106
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 209                        23                          33             6.6
# 241                        24                          46             6.5
# 253                        12                          15             5.2
# 312                        25                          54             8.5
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 209      3.9                         NaN        1
# 241      3.1                         NaN        1
# 253      2.7                         NaN        2
# 312      4.8                         NaN        2

# %%
data.loc[data['Albumin_and_Globulin_Ratio'].isnull()==True,'Albumin_and_Globulin_Ratio']=0.95

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %% [markdown]
# Data Visualization

# %% [markdown]
# Univariate Analysis

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.distplot(data["Total_Bilirubin"])

# %%
sns.histplot(data["Alkaline_Phosphotase"])

# %% [markdown]
# Bivariate Analysis

# %%
sns.relplot(x="Albumin_and_Globulin_Ratio",y="Albumin",data=data,hue="Gender")

# %% [markdown]
# Multi - Variate Analysis

# %%
sns.countplot(data.Gender,palette='Purples')
plt.show()

# %%
sns.catplot(x="Gender",y="Direct_Bilirubin",data=data)

# %%
plt.bar(data.Gender,data.Age)
plt.xlabel('Gender')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
fig=plt.figure(figsize=(10,6))
sns.heatmap(data.corr(),cmap='coolwarm')

# %%
diseased=data[data['Dataset']==1]
diseased
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 576   32    Male             15.0               8.2                   289
# 577   32    Male             12.7               8.4                   190
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 576                        58                          80             5.3
# 577                        28                          47             5.4
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 576      2.2                        0.70        1
# 577      2.6                        0.90        1
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
#
# [416 rows x 11 columns]

# %%
sns.set_style('darkgrid')
fig=plt.figure(figsize=(10,6))
sns.distplot(diseased['Age'],bins=10,kde=False,axlabel='AGE',color='green')

# %%
sns.countplot(x='Gender',data=diseased,palette='coolwarm')

# %%
sns.countplot(data=data,x='Dataset')
Ld,N=data['Dataset'].value_counts()
print("Liver Disease",Ld)
print("No Liver Disease",N)
plt.show()
# Out:
# Liver Disease 416
# No Liver Disease 167

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# Male      441
# Female    142
# Name: Gender, dtype: int64

# %%
df = pd.get_dummies(data, columns = ['Gender'])
print(df)
# Out:
#      Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65              0.7               0.1                   187
# 1     62             10.9               5.5                   699
# 2     62              7.3               4.1                   490
# 3     58              1.0               0.4                   182
# 4     72              3.9               2.0                   195
# ..   ...              ...               ...                   ...
# 578   60              0.5               0.1                   500
# 579   40              0.6               0.1                    98
# 580   52              0.8               0.2                   245
# 581   31              1.3               0.5                   184
# 582   38              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset  Gender_Female  Gender_Male
# 0        3.3                        0.90        1              1            0
# 1        3.2                        0.74        1              0            1
# 2        3.3                        0.89        1              0            1
# 3        3.4                        1.00        1              0            1
# 4        2.4                        0.40        1              0            1
# ..       ...                         ...      ...            ...          ...
# 578      1.6                        0.37        2              0            1
# 579      3.2                        1.10        1              0            1
# 580      3.2                        1.00        1              0            1
# 581      3.4                        1.00        1              0            1
# 582      4.4                        1.50        2              0            1
#
# [583 rows x 12 columns]

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.drop('Dataset',axis=1))
scaled_features = scaler.transform(df.drop('Dataset',axis=1))
liver_scaled = pd.DataFrame(scaled_features,columns=df.columns[:-1])
liver_scaled.head()
# Out:
#         Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0  1.252098        -0.418878         -0.493964             -0.426715
# 1  1.066637         1.225171          1.430423              1.682629
# 2  1.066637         0.644919          0.931508              0.821588
# 3  0.819356        -0.370523         -0.387054             -0.447314
# 4  1.684839         0.096902          0.183135             -0.393756
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                 -0.354665                   -0.318393        0.292120
# 1                 -0.091599                   -0.034333        0.937566
# 2                 -0.113522                   -0.145186        0.476533
# 3                 -0.365626                   -0.311465        0.292120
# 4                 -0.294379                   -0.176363        0.753153
#
#     Albumin  Albumin_and_Globulin_Ratio   Dataset  Gender_Female
# 0  0.198969                   -0.147961  1.762281      -1.762281
# 1  0.073157                   -0.650760 -0.567446       0.567446
# 2  0.198969                   -0.179386 -0.567446       0.567446
# 3  0.324781                    0.166288 -0.567446       0.567446
# 4 -0.933340                   -1.719207 -0.567446       0.567446

# %% [markdown]
# Splitting the dataset into independent and dependent variable

# %%
X=liver_scaled
y=df['Dataset']

# %% [markdown]
# Splitting the independent and dependent features into train and test set

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score,accuracy_score,recall_score,f1_score,mean_absolute_error,mean_squared_error
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
y_test.value_counts()
# Out:
# 1    125
# 2     50
# Name: Dataset, dtype: int64

# %% [markdown]
# MODEL BUILDING

# %% [markdown]
# Train and test the model using classification algorithms, Model Evaluation

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
param_grid = {'C': [0.1,1, 10,50,100,200,1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.683 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.654 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.683 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.683 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.728 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.683 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.622 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.691 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END .........C=50, gamma=1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 2/5] END .........C=50, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 3/5] END .........C=50, gamma=1, kernel=rbf;, score=0.646 total time=   0.0s
# [CV 4/5] END .........C=50, gamma=1, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 5/5] END .........C=50, gamma=1, kernel=rbf;, score=0.630 total time=   0.0s
# [CV 1/5] END .......C=50, gamma=0.1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 2/5] END .......C=50, gamma=0.1, kernel=rbf;, score=0.671 total time=   0.0s
# [CV 3/5] END .......C=50, gamma=0.1, kernel=rbf;, score=0.671 total time=   0.0s
# [CV 4/5] END .......C=50, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END .......C=50, gamma=0.1, kernel=rbf;, score=0.691 total time=   0.0s
# [CV 1/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.634 total time=   0.0s
# [CV 3/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 4/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.630 total time=   0.0s
# [CV 1/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ....C=50, gamma=0.0001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ....C=50, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ....C=50, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ....C=50, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ....C=50, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.683 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.659 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.610 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.704 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.654 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.610 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.671 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ........C=200, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 2/5] END ........C=200, gamma=1, kernel=rbf;, score=0.683 total time=   0.0s
# [CV 3/5] END ........C=200, gamma=1, kernel=rbf;, score=0.659 total time=   0.0s
# [CV 4/5] END ........C=200, gamma=1, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 5/5] END ........C=200, gamma=1, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END ......C=200, gamma=0.1, kernel=rbf;, score=0.671 total time=   0.0s
# [CV 2/5] END ......C=200, gamma=0.1, kernel=rbf;, score=0.622 total time=   0.0s
# [CV 3/5] END ......C=200, gamma=0.1, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ......C=200, gamma=0.1, kernel=rbf;, score=0.704 total time=   0.0s
# [CV 5/5] END ......C=200, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 1/5] END .....C=200, gamma=0.01, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END .....C=200, gamma=0.01, kernel=rbf;, score=0.622 total time=   0.0s
# [CV 3/5] END .....C=200, gamma=0.01, kernel=rbf;, score=0.671 total time=   0.0s
# [CV 4/5] END .....C=200, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END .....C=200, gamma=0.01, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END ....C=200, gamma=0.001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ....C=200, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ....C=200, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ....C=200, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ....C=200, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END ...C=200, gamma=0.0001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ...C=200, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ...C=200, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ...C=200, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ...C=200, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.683 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.659 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.659 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.646 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.695 total time=   0.1s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.654 total time=   0.1s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.610 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.646 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.654 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.707 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.716 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 50, 100, 200, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
svm_predictions=grid.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
svm_acc=accuracy_score(y_test,svm_predictions)
svm_prec=precision_score(y_test,svm_predictions)
svm_rec=recall_score(y_test,svm_predictions)
svm_f1=f1_score(y_test,svm_predictions)
svm_mas=mean_absolute_error(y_test,svm_predictions)
svm_rms=np.sqrt(mean_squared_error(y_test,svm_predictions))

# %%
print(classification_report(y_test,svm_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.71      1.00      0.83       125
#            2       0.00      0.00      0.00        50
#
#     accuracy                           0.71       175
#    macro avg       0.36      0.50      0.42       175
# weighted avg       0.51      0.71      0.60       175

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lg_predictions=lg.predict(X_test)

# %%
lg_acc=accuracy_score(y_test,lg_predictions)
lg_prec=precision_score(y_test,lg_predictions)
lg_rec=recall_score(y_test,lg_predictions)
lg_f1=f1_score(y_test,lg_predictions)
lg_mas=mean_absolute_error(y_test,lg_predictions)
lg_rms=np.sqrt(mean_squared_error(y_test,lg_predictions))

# %%
print(classification_report(y_test,lg_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.77      0.89      0.82       125
#            2       0.53      0.32      0.40        50
#
#     accuracy                           0.73       175
#    macro avg       0.65      0.60      0.61       175
# weighted avg       0.70      0.73      0.70       175

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc= RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=600)

# %%
rfc_predictions=rfc.predict(X_test)

# %%
rfc_acc=accuracy_score(y_test,rfc_predictions)
rfc_prec=precision_score(y_test,rfc_predictions)
rfc_rec=recall_score(y_test,rfc_predictions)
rfc_f1=f1_score(y_test,rfc_predictions)
rfc_mas=mean_absolute_error(y_test,rfc_predictions)
rfc_rms=np.sqrt(mean_squared_error(y_test,rfc_predictions))

# %%
print(classification_report(y_test,rfc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.89      0.84       125
#            2       0.61      0.44      0.51        50
#
#     accuracy                           0.76       175
#    macro avg       0.70      0.66      0.68       175
# weighted avg       0.75      0.76      0.75       175

# %% [markdown]
# DECISION TREE CLASSIFIER ALGORITHM

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree_predictions=dtree.predict(X_test)

# %%
dtree_acc=accuracy_score(y_test,dtree_predictions)
dtree_prec=precision_score(y_test,dtree_predictions)
dtree_rec=recall_score(y_test,dtree_predictions)
dtree_f1=f1_score(y_test,dtree_predictions)
dtree_mas=mean_absolute_error(y_test,dtree_predictions)
dtree_rms=np.sqrt(mean_squared_error(y_test,dtree_predictions))

# %%
print(classification_report(y_test,dtree_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.68      0.71       125
#            2       0.35      0.44      0.39        50
#
#     accuracy                           0.61       175
#    macro avg       0.55      0.56      0.55       175
# weighted avg       0.64      0.61      0.62       175

# %% [markdown]
# K NEAREST NEIGHBOURS ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
error_rate = []

for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
error_rate[36]
# Out:
# 0.2914285714285714

# %%
knn = KNeighborsClassifier(n_neighbors=36)

knn.fit(X_train,y_train)
knn_predictions = knn.predict(X_test)

print('WITH K=36')
print('\n')
print(classification_report(y_test,knn_predictions))
# Out:
# WITH K=36
#
#
#               precision    recall  f1-score   support
#
#            1       0.72      0.98      0.83       125
#            2       0.33      0.02      0.04        50
#
#     accuracy                           0.71       175
#    macro avg       0.52      0.50      0.43       175
# weighted avg       0.61      0.71      0.60       175

# %%
knn_acc=accuracy_score(y_test,knn_predictions)
knn_prec=precision_score(y_test,knn_predictions)
knn_rec=recall_score(y_test,knn_predictions)
knn_f1=f1_score(y_test,knn_predictions)
knn_mas=mean_absolute_error(y_test,knn_predictions)
knn_rms=np.sqrt(mean_squared_error(y_test,knn_predictions))

# %% [markdown]
# Analyzing the different machine learning models

# %%
d={'Machine Learning Algorithm':['Support Vector Machine','Logistic Regression','Random Forest Classifier','Decision Tree Classifier','K Nearest Neighbours'],'Accuracy_Score':[svm_acc*100,lg_acc*100,rfc_acc*100,dtree_acc*100,knn_acc*100],'Precision_Score':[svm_prec*100,lg_prec*100,rfc_prec*100,dtree_prec*100,knn_prec*100],'Recall_Score':[svm_rec*100,lg_rec*100,rfc_rec*100,dtree_rec*100,knn_rec*100],'F1_Score':[svm_f1*100,lg_f1*100,rfc_f1*100,dtree_f1*100,knn_f1*100],'Mean_Absolute_Error':[svm_mas*100,lg_mas*100,rfc_mas*100,dtree_mas*100,knn_mas*100],'Root_Mean_Square_Error':[svm_rms*100,lg_rms*100,rfc_rms*100,dtree_rms*100,knn_rms*100]}

# %%
results=pd.DataFrame(d)

# %%
results
# Out:
#   Machine Learning Algorithm  Accuracy_Score  Precision_Score  Recall_Score  \
# 0     Support Vector Machine       71.428571        71.428571         100.0
# 1        Logistic Regression       72.571429        76.551724          88.8
# 2   Random Forest Classifier       76.000000        79.856115          88.8
# 3   Decision Tree Classifier       61.142857        75.221239          68.0
# 4       K Nearest Neighbours       70.857143        71.511628          98.4
#
#     F1_Score  Mean_Absolute_Error  Root_Mean_Square_Error
# 0  83.333333            28.571429               53.452248
# 1  82.222222            27.428571               52.372294
# 2  84.090909            24.000000               48.989795
# 3  71.428571            38.857143               62.335498
# 4  82.828283            29.142857               53.984125

# %%
results.plot.bar(x='Machine Learning Algorithm',figsize=(14,7))
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))

# %% [markdown]
# Save The Model

# %%
import pickle
pickle.dump(model, open('SVM.pkl','wb'))

# %%
import pickle
pickle.dump(lg, open('LogReg.pkl','wb'))

# %%
import pickle
pickle.dump(rfc, open('RanForClas.pkl','wb'))

# %%
import pickle
pickle.dump(dtree, open('dectree.pkl','wb'))

# %%
import pickle
pickle.dump(knn, open('KNN.pkl','wb'))
